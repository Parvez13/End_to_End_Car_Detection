# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
## Install YOLOV8
# !pip install ultralytics==8.0.20
from IPython import display
display.clear_output()
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.0.20 🚀 Python-3.10.11 torch-2.0.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 23.3/78.2 GB disk)

# %%
# Import YOLO
from ultralytics import YOLO 
from IPython.display import display, Image

# %%
# %cd /content/drive/MyDrive/OBJECT_DETECTION/CarDetection
# Out:
# /content/drive/MyDrive/OBJECT_DETECTION/CarDetection

# %%
ls
# Out:
# data.zip

# %% [markdown]
# ### Download dataset

# %%
# Download and unzip the data
# !curl -L data.zip; unzip data.zip; rm data.zip
# Out:
# curl: (6) Could not resolve host: data.zip
# Archive:  data.zip
#   inflating: data/data.yaml
#    creating: data/test/
#    creating: data/test/images/
#   inflating: data/test/images/vid_5_25100.jpg
#   inflating: data/test/images/vid_5_25120.jpg
#   inflating: data/test/images/vid_5_25140.jpg
#   inflating: data/test/images/vid_5_25160.jpg
#   inflating: data/test/images/vid_5_25180.jpg
#   inflating: data/test/images/vid_5_25200.jpg
#   inflating: data/test/images/vid_5_25220.jpg
#   inflating: data/test/images/vid_5_25240.jpg
#   inflating: data/test/images/vid_5_25260.jpg
#   inflating: data/test/images/vid_5_26320.jpg
#   inflating: data/test/images/vid_5_26400.jpg
#   inflating: data/test/images/vid_5_26420.jpg
#   inflating: data/test/images/vid_5_26560.jpg
#   inflating: data/test/images/vid_5_26580.jpg
#   inflating: data/test/images/vid_5_26600.jpg
#   inflating: data/test/images/vid_5_26620.jpg
#   inflating: data/test/images/vid_5_26640.jpg
# ...

# %% [markdown]
# ### Model Training(yolov8)

# %%
# %cd /content/drive/MyDrive/OBJECT_DETECTION/CarDetection/data

# !yolo task=detect model=train model=yolov8s.pt data=data.yaml epochs=10 imgsz=224 plots=True
# Out:
# /content/drive/MyDrive/OBJECT_DETECTION/CarDetection/data
# WARNING ⚠️ 'mode' is missing. Valid modes are ('train', 'val', 'predict', 'export'). Using default 'mode=train'.
# ...
# 100% 21.5M/21.5M [00:00<00:00, 162MB/s]
#
# Ultralytics YOLOv8.0.20 🚀 Python-3.10.11 torch-2.0.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %% [markdown]
# ### Evaluate custom YOLOV8 detector performance

# %%
## 

# Start tensorboard
# Launch after you have started training
# logs save in the folder "runs"
# %load_ext tensorboard
# %tensorboard --logdir runs

# %%
# we can also output some older school graphs if the tensor board isn't working for whatever reason... 
Image(filename='/content/drive/MyDrive/OBJECT_DETECTION/CarDetection/data/runs/detect/train/results.png', width=1000)  # view results.png

# %%
Image(filename='/content/drive/MyDrive/OBJECT_DETECTION/CarDetection/data/runs/detect/train/train_batch0.jpg')

# %%
Image(filename='/content/drive/MyDrive/OBJECT_DETECTION/CarDetection/data/runs/detect/train/confusion_matrix.png')
